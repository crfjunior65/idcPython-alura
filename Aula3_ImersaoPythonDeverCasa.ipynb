# %%
'Junior'
# Out:
# 'Junior'

# %%
print('Boas Vindas a Aula Puthon')
# Out:
# Boas Vindas a Aula Puthon

# %%
nome = 'Junior Fernandes'

# %%
nome
# Out:
# 'Junior Fernandes'

# %%
import pandas as pd

# %%
from datetime import date

# %%
data_atual = date.today()
print(data_atual)
# Out:
# 2025-08-07

# %%
data_em_texto = "0{}/0{}/{}".format(data_atual.day, data_atual.month,data_atual.year)
print(data_em_texto)
# Out:
# 07/08/2025

# %%
data_em_texto = data_atual.strftime("%d/%m/%Y")
print(data_em_texto)
# Out:
# 07/08/2025

# %%
from datetime import datetime, timezone
data_e_hora_atuais = datetime.now()
data_e_hora_em_texto = data_e_hora_atuais.strftime("%d/%m/%Y %H:%M")
print(data_e_hora_em_texto)
# Out:
# 07/08/2025 19:38

# %%
data_e_hora_em_texto = "01/03/2018 12:30"
data_e_hora = datetime.strptime(data_e_hora_em_texto, "%d/%m/%Y %H:%M")
print(data_e_hora)
# Out:
# 2018-03-01 12:30:00

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print(f"O DataFrame possui {linhas} linhas e {colunas} colunas.")
# Out:
# O DataFrame possui 133349 linhas e 11 colunas.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Dicionário de renomeação
novos_nomes = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

# Aplicando renomeação
df.rename(columns=novos_nomes, inplace=True)

# Verificando resultado
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
# O método .value_counts() serve para contar quantas vezes cada valor único aparece em uma coluna.
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
senioridade = {
    'SE': 'senior',
    'MI': 'pleno',
    'EN': 'junior',
    'EX': 'executivo'
}
df['senioridade'] = df['senioridade'].replace(senioridade)
df['senioridade'].value_counts()
# Out:
# senioridade
# senior       77241
# pleno        40465
# junior       12443
# executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'integral',
    'PT': 'parcial',
    'CT': 'contrato',
    'FL': 'freelancer'
}
df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# integral      132563
# contrato         394
# parcial          376
# freelancer        16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'L': 'grande',
    'S': 'pequena',
    'M': 'media'

}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# media      129561
# grande       3574
# pequena       214
# Name: count, dtype: int64

# %%
mapa_trabalho = {
    0: 'presencial',
    100: 'remoto',
    50: 'hibrido'
}

df['remoto'] = df['remoto'].replace(mapa_trabalho)
df['remoto'].value_counts()
# Out:
# remoto
# presencial    105312
# remoto         27718
# hibrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df.describe(include='object')
# Out:
#        senioridade  contrato           cargo   moeda residencia      remoto  \
# count       133349    133349          133349  133349     133349      133349
# unique           4         4             390      26        102           3
# top         senior  integral  Data Scientist     USD         US  presencial
# freq         77241    132563           17314  126140     119579      105312
#
#        empresa tamanho_empresa
# count   133349          133349
# unique      95               3
# top         US           media
# freq    119641          129561

# %% [markdown]
# Aula 02

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df["ano"].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade  contrato                      cargo  salario moeda  \
# 5588    NaN      senior  integral            Product Manager   184500   USD
# 59692   NaN       pleno  integral                   Engineer   110000   USD
# 59710   NaN      junior  integral             Data Scientist   208800   USD
# 59759   NaN      senior  integral          Software Engineer   135000   USD
# 59789   NaN      senior  integral                   Engineer   112000   USD
# 131000  NaN      senior  integral  Machine Learning Engineer   163800   USD
# 131006  NaN      senior  integral     Data Analytics Manager   204500   USD
# 133054  NaN      junior  integral             Data Scientist    40000   USD
# 133281  NaN       pleno  integral  Machine Learning Engineer   180000   PLN
# 133317  NaN       pleno  integral             Data Scientist   130000   USD
#
#            usd residencia      remoto empresa tamanho_empresa
# 5588    184500         US  presencial      US           media
# ...

# %% [markdown]
# Criação de um DataFrame para validar metodos de Correção da Dase de Dados

# %% [markdown]
# Preenchimento com a Media

# %%
import numpy as np

df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carla", "Daniel", "Eduarda"],
    'salario': [5000, 2000, np.nan, 4000, np.nan]
})

df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
df_salarios
# Out:
#       nome  salario  salario_media
# 0      Ana   5000.0        5000.00
# 1    Bruno   2000.0        2000.00
# 2    Carla      NaN        3666.67
# 3   Daniel   4000.0        4000.00
# 4  Eduarda      NaN        3666.67

# %%
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())
df_salarios
# Out:
#       nome  salario  salario_media  salario_mediana
# 0      Ana   5000.0        5000.00           5000.0
# 1    Bruno   2000.0        2000.00           2000.0
# 2    Carla      NaN        3666.67           4000.0
# 3   Daniel   4000.0        4000.00           4000.0
# 4  Eduarda      NaN        3666.67           4000.0

# %% [markdown]
# Novo DataFrame de Temperatura

# %%
df_temperatura = pd.DataFrame({
    'data': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
    'temperatura': [25, 28, np.nan, np.nan, 30]
})

df_temperatura['preenchido_ffill'] = df_temperatura['temperatura'].fillna(method='ffill')

df_temperatura
# Out:
# /tmp/ipython-input-3044175036.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_temperatura['preenchido_ffill'] = df_temperatura['temperatura'].fillna(method='ffill')
#          data  temperatura  preenchido_ffill
# 0  2023-01-01         25.0              25.0
# 1  2023-01-02         28.0              28.0
# 2  2023-01-03          NaN              28.0
# 3  2023-01-04          NaN              28.0
# 4  2023-01-05         30.0              30.0

# %%
df_temperatura = pd.DataFrame({
    'data': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
    'temperatura': [25, 28, np.nan, np.nan, 30]
})

df_temperatura['preenchido_bfill'] = df_temperatura['temperatura'].fillna(method='bfill')

df_temperatura
# Out:
# /tmp/ipython-input-2813786604.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_temperatura['preenchido_bfill'] = df_temperatura['temperatura'].fillna(method='bfill')
#          data  temperatura  preenchido_bfill
# 0  2023-01-01         25.0              25.0
# 1  2023-01-02         28.0              28.0
# 2  2023-01-03          NaN              30.0
# 3  2023-01-04          NaN              30.0
# 4  2023-01-05         30.0              30.0

# %% [markdown]
# Novo DF, para preenchimento estatico

# %%
df_cidades = pd.DataFrame({
    'nome': ['Ana', 'Paulo', 'Junior', 'Roberto', 'Laura'],
    'cidade': ['São Paulo', np.nan, 'Belo Horizonte', np.nan, 'Curitiba'],
    'temperatura': [25, 28, 27, 31, 30]
})

df_cidades['cidade_preenchida'] = df_cidades["cidade"].fillna("Nao Preenchida")

df_cidades
# Out:
#       nome          cidade  temperatura cidade_preenchida
# 0      Ana       São Paulo           25         São Paulo
# 1    Paulo             NaN           28    Nao Preenchida
# 2   Junior  Belo Horizonte           27    Belo Horizonte
# 3  Roberto             NaN           31    Nao Preenchida
# 4    Laura        Curitiba           30          Curitiba

# %% [markdown]
# Tratar DF com  outro DF sem os Dados nulos

# %%
df_limpo = df.dropna()
df_limpo
# Out:
#            ano senioridade  contrato                     cargo  salario moeda  \
# 0       2025.0      senior  integral        Solutions Engineer   214000   USD
# 1       2025.0      senior  integral        Solutions Engineer   136000   USD
# 2       2025.0       pleno  integral             Data Engineer   158800   USD
# 3       2025.0       pleno  integral             Data Engineer   139200   USD
# 4       2025.0      junior  integral             Data Engineer    90000   USD
# ...        ...         ...       ...                       ...      ...   ...
# 133344  2020.0      senior  integral            Data Scientist   412000   USD
# 133345  2021.0       pleno  integral  Principal Data Scientist   151000   USD
# 133346  2020.0      junior  integral            Data Scientist   105000   USD
# 133347  2020.0      junior  contrato     Business Data Analyst   100000   USD
# 133348  2021.0      senior  integral            Data Scientist  7000000   INR
#
# ...

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %% [markdown]
# Converter o tipo do  Dado

# %%
df_limpo = df_limpo.astype({'ano': 'int64'})
# ou pode ser assim: df_limpo = df_limpo.assign(ano = df_lompo['ano'].astype('int64'))
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df_limpo.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333390e+05  133339.000000
# mean     2024.358770  1.632846e+05  157619.079339
# std         0.680627  2.173937e+05   74289.262933
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060065e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 12.2+ MB

# %% [markdown]
# Mostrar como salvar um arquivo após ter sido limpo e preparado para análises posteriores:

# %%
df_limpo.to_csv('dados-imersao-07082025.csv', index=False)

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %% [markdown]
# AULA 03 - Exibição Grafica

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df_limpo["senioridade"].value_counts().plot(kind="bar", title="Distribuição de Senioridade")
# Out:
# <Axes: title={'center': 'Distribuição de Senioridade'}, xlabel='senioridade'>

# %% [markdown]
# Bibliotecas Python indicadas pata Graficos: Matplotlib e Seaborn

# %% [markdown]
# Seaborn - Biblioteca Grafica - Dados estatisticos

# %%
import seaborn as sns

# %%
sns.barplot(x="senioridade", y="usd", data=df_limpo)
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="senioridade", y="usd", data=df_limpo)
plt.title("Salários Medios por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Médio Anual (USD)")
plt.show()

# %%
df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=False)
# Out:
# senioridade
# executivo    202027.667813
# senior       172850.838301
# pleno        143044.845979
# junior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['executivo', 'senior', 'pleno', 'junior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x="senioridade", y="usd", order=ordem)
plt.title("Salários Medios por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Médio Anual (USD)")
plt.show()

# %%
df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=True)
# Out:
# senioridade
# junior        99034.963267
# pleno        143044.845979
# senior       172850.838301
# executivo    202027.667813
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=True).index
ordem
# Out:
# Index(['junior', 'pleno', 'senior', 'executivo'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x="senioridade", y="usd", order=ordem)
plt.title("Salários Medios por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Médio Anual (USD)")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df_limpo["usd"], bins=100, kde=True)
plt.title("Distribuição Salarial Anual")
plt.xlabel("Salário Anual (USD)")
plt.ylabel("Frequência")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_limpo["usd"])
plt.title("Boxplot Distribuição Salarial Anual")
plt.xlabel("Salário Anual (USD)")
plt.show()

# %%
ordem_senoridade = ["junior", "pleno", "senior", "executivo"]

plt.figure(figsize=(8, 5))
sns.boxplot(x="senioridade", y="usd", data=df_limpo, order=ordem_senoridade)
plt.title("Boxplot Distribuição Salarial Anual por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Anual (USD)")
plt.show()

# %%
#ordem_senoridade = ["junior", "pleno", "senior", "executivo"]

plt.figure(figsize=(8, 5))
sns.boxplot(x="senioridade", y="usd", data=df_limpo, order=ordem_senoridade, palette="Set2", hue="senioridade")
plt.title("Boxplot Distribuição Salarial Anual por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Anual (USD)")
plt.show()

# %%
import plotly.express as px

# %%
senioridade_media_salarial = df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=False).reset_index()
senioridade_media_salarial

fig = px.bar(senioridade_media_salarial,
             x='senioridade',
             y='usd',
             title="Média Salarial por Senioridade",
             labels={"senioridade": "Senioridade", "usd": "Média Salarial Anual (USD)"})

fig.update_layout(xaxis_title="Senioridade", yaxis_title="Média Salarial Anual (USD)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_senioridade_media = df_limpo.groupby("senioridade")["usd"].mean().reset_index()
df_senioridade_media = df_senioridade_media.sort_values("usd", ascending=False)

fig = px.bar(df_senioridade_media, x="senioridade", y="usd", title="Média Salarial por Senioridade")
fig.update_layout(xaxis_title="Senioridade", yaxis_title="Média Salarial Anual (USD)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem  = df_limpo["remoto"].value_counts().reset_index()
remoto_contagem.columns = ["remoto", "quantidade"]
remoto_contagem
# Out:
#        remoto  quantidade
# 0  presencial      105305
# 1      remoto       27716
# 2     hibrido         318

# %%
remoto_contagem  = df_limpo["remoto"].value_counts().reset_index()
remoto_contagem.columns = ["tipo_trabalho", "quantidade"]
remoto_contagem
# Out:
#   tipo_trabalho  quantidade
# 0    presencial      105305
# 1        remoto       27716
# 2       hibrido         318

# %%
ordem_senoridade = ["junior", "pleno", "senior", "executivo"]
'''
plt.figure(figsize=(8, 5))
sns.boxplot(x="senioridade", y="usd", data=df_limpo, order=ordem_senoridade)
plt.title("Boxplot Distribuição Salarial Anual por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Anual (USD)")
plt.show()'''

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Distribuição de Tipo de Trabalho')
fig.update_layout(xaxis_title="Tipo de Trabalho", yaxis_title="Quantidade")
fig.show()

#
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ordem_senoridade = ["junior", "pleno", "senior", "executivo"]
'''
plt.figure(figsize=(8, 5))
sns.boxplot(x="senioridade", y="usd", data=df_limpo, order=ordem_senoridade)
plt.title("Boxplot Distribuição Salarial Anual por Senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário Anual (USD)")
plt.show()'''

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Distribuição de Tipo de Trabalho',
             hole=0.5)
fig.update_layout(xaxis_title="Tipo de Trabalho", yaxis_title="Quantidade")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Distribuição de Tipo de Trabalho',
             hole=0.5)
fig.update_traces(textinfo='percent+label')
fig.update_layout(xaxis_title="Tipo de Trabalho", yaxis_title="Quantidade")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Formatar Data Framos que tem muitas colunas
#pd.set_option('display.max_columns', None)
#Formatar Data Frames que tam muitas Linhas
#pd.set_option('display.max_rows', None)
#Deixar o Fortamo Float com duas Casas decimais
#pd.set_option.display.float_format = '{:.2f}'.format

# %% [markdown]
# Tarefa de Casa para proxima aula
# Salario medio por Pais, por Cargo e deixa em evidencia o Cargo de Ciencia de Dados(Data Scients)

# %%
df_limpo.head(20)
# Out:
#      ano senioridade  contrato               cargo  salario moeda     usd  \
# 0   2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1   2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2   2025       pleno  integral       Data Engineer   158800   USD  158800
# 3   2025       pleno  integral       Data Engineer   139200   USD  139200
# 4   2025      junior  integral       Data Engineer    90000   USD   90000
# 5   2025      junior  integral       Data Engineer    80000   USD   80000
# 6   2025      senior  integral      Data Scientist   185000   USD  185000
# 7   2025      senior  integral      Data Scientist   148000   USD  148000
# 8   2025       pleno  integral      Data Scientist   135000   USD  135000
# 9   2025       pleno  integral      Data Scientist   108000   USD  108000
# 10  2025       pleno  integral        BI Developer   118000   USD  118000
# 11  2025       pleno  integral        BI Developer    51000   USD   51000
# ...

# %% [markdown]
# Primeiro ensaio estou usando  IA DeepSeek, com o prompt Simples.

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

## 1. Pré-processamento dos dados =============================================

# Calcular salário médio e contagem por país e cargo
df_agg = df_limpo.groupby(['residencia', 'cargo'])['usd'].agg(['mean', 'count']).reset_index()
df_agg.rename(columns={'mean': 'salario_medio', 'count': 'qtd_registros'}, inplace=True)

# Filtrar combinações com poucos registros (ajuste o valor conforme necessário)
df_agg = df_agg[df_agg['qtd_registros'] >= 10]

# Criar coluna de destaque
df_agg['destaque'] = df_agg['cargo'].apply(
    lambda x: 'Data Scientist' if 'Data Scientist' in x else 'Outros Cargos')

# Ordenar por salário médio
df_agg = df_agg.sort_values('salario_medio', ascending=False)

# Selecionar top países (ajuste conforme necessário)
top_paises = df_agg['residencia'].value_counts().head(15).index
df_agg = df_agg[df_agg['residencia'].isin(top_paises)]

## 2. Gráfico de Barras Interativo ============================================

fig = px.bar(
    df_agg,
    x='residencia',
    y='salario_medio',
    color='destaque',
    color_discrete_map={
        'Data Scientist': '#EF553B',  # Vermelho
        'Outros Cargos': '#636EFA'   # Azul
    },
    hover_data=['cargo', 'qtd_registros'],
    labels={
        'residencia': 'País',
        'salario_medio': 'Salário Médio (USD)',
        'destaque': 'Cargo'
    },
    title='<b>Salário Médio por País</b><br><sup>Destaque para Data Scientists</sup>',
    text='salario_medio',
    height=600
)

# Formatar valores no hover
fig.update_traces(
    texttemplate='$%{text:,.0f}',
    textposition='outside',
    hovertemplate=(
        "<b>País:</b> %{x}<br>"
        "<b>Cargo:</b> %{customdata[0]}<br>"
        "<b>Salário Médio:</b> $%{y:,.0f}<br>"
        "<b>Registros:</b> %{customdata[1]}"
    )
)

# Melhorar layout
fig.update_layout(
    uniformtext_minsize=8,
    uniformtext_mode='hide',
    xaxis_tickangle=-45,
    yaxis_tickprefix='$',
    yaxis_tickformat=',.0f',
    hoverlabel=dict(
        bgcolor="white",
        font_size=12,
        font_family="Rockwell"
    ),
    legend_title_text='Tipo de Cargo',
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    margin=dict(l=20, r=20, t=80, b=20)
)

## 3. Gráfico Adicional - Salário por Cargo ===================================

# Criar figura com subplots
fig2 = make_subplots(rows=1, cols=1)

# Adicionar todos os cargos em cinza
fig2.add_trace(
    go.Bar(
        x=df_agg['cargo'],
        y=df_agg['salario_medio'],
        name='Outros Cargos',
        marker_color='lightgray',
        hovertemplate='<b>Cargo:</b> %{x}<br><b>Salário:</b> $%{y:,.0f}<extra></extra>'
    )
)

# Adicionar Data Scientists em destaque
df_ds = df_agg[df_agg['destaque'] == 'Data Scientist']
fig2.add_trace(
    go.Bar(
        x=df_ds['cargo'],
        y=df_ds['salario_medio'],
        name='Data Scientist',
        marker_color='#EF553B',
        hovertemplate='<b>Cargo:</b> %{x}<br><b>Salário:</b> $%{y:,.0f}<extra></extra>'
    )
)

# Atualizar layout
fig2.update_layout(
    title='<b>Salário Médio por Cargo</b><br><sup>Destaque para Data Scientists</sup>',
    xaxis_title='Cargo',
    yaxis_title='Salário Médio (USD)',
    xaxis_tickangle=-45,
    yaxis_tickprefix='$',
    yaxis_tickformat=',.0f',
    barmode='group',
    height=600,
    showlegend=True,
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)'
)

## 4. Mostrar os gráficos =====================================================

# Mostrar o primeiro gráfico
fig.show()

# Mostrar o segundo gráfico (se houver Data Scientists)
if not df_ds.empty:
    fig2.show()
else:
    print("Nenhum Data Scientist encontrado nos dados filtrados.")

## 5. Opção para salvar os gráficos ===========================================
# fig.write_html("salario_por_pais.html")
# fig2.write_html("salario_por_cargo.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Pedimos para mudar as cores dos Textos dos Graficos

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

## 1. Configuração do Tema Escuro =============================================
dark_template = {
    'layout': {
        'paper_bgcolor': 'rgba(0,0,0,0)',
        'plot_bgcolor': 'rgba(0,0,0,0)',
        'font': {'color': 'white'},
        'xaxis': {
            'gridcolor': 'rgba(100,100,100,0.2)',
            'linecolor': 'rgba(100,100,100,0.8)',
            'zerolinecolor': 'rgba(100,100,100,0.4)'
        },
        'yaxis': {
            'gridcolor': 'rgba(100,100,100,0.2)',
            'linecolor': 'rgba(100,100,100,0.8)',
            'zerolinecolor': 'rgba(100,100,100,0.4)'
        },
        'hoverlabel': {
            'bgcolor': '#1a1a1a',
            'font': {'color': 'white'}
        }
    }
}

## 2. Pré-processamento (mesmo do anterior) ===================================
df_agg = df_limpo.groupby(['residencia', 'cargo'])['usd'].agg(['mean', 'count']).reset_index()
df_agg.rename(columns={'mean': 'salario_medio', 'count': 'qtd_registros'}, inplace=True)
df_agg = df_agg[df_agg['qtd_registros'] >= 10]
df_agg['destaque'] = df_agg['cargo'].apply(
    lambda x: 'Data Scientist' if 'Data Scientist' in x else 'Outros Cargos')
df_agg = df_agg.sort_values('salario_medio', ascending=False)
top_paises = df_agg['residencia'].value_counts().head(15).index
df_agg = df_agg[df_agg['residencia'].isin(top_paises)]

## 3. Gráfico de Barras - Versão Tema Escuro ===================================
fig = px.bar(
    df_agg,
    x='residencia',
    y='salario_medio',
    color='destaque',
    color_discrete_map={
        'Data Scientist': '#FF6B6B',  # Vermelho claro
        'Outros Cargos': '#4ECDC4'    # Turquesa
    },
    hover_data=['cargo', 'qtd_registros'],
    labels={
        'residencia': 'País',
        'salario_medio': 'Salário Médio (USD)',
        'destaque': 'Cargo'
    },
    title='<b>Salário Médio por País</b><br><sup>Destaque para Data Scientists</sup>',
    height=600,
    template=dark_template
)

# Melhorar formatação
fig.update_traces(
    texttemplate='$%{y:,.0f}',
    textposition='outside',
    textfont={'color': 'white'},
    hovertemplate=(
        "<b>País:</b> %{x}<br>"
        "<b>Cargo:</b> %{customdata[0]}<br>"
        "<b>Salário Médio:</b> $%{y:,.0f}<br>"
        "<b>Registros:</b> %{customdata[1]}"
    )
)

fig.update_layout(
    xaxis_tickangle=-45,
    yaxis_tickprefix='$',
    yaxis_tickformat=',.0f',
    legend_title_text='Tipo de Cargo',
    margin=dict(l=20, r=20, t=80, b=20),
    hovermode='x unified'
)

## 4. Gráfico por Cargo - Versão Tema Escuro ===================================
fig2 = make_subplots(rows=1, cols=1)

# Adicionar barras para todos os cargos
fig2.add_trace(
    go.Bar(
        x=df_agg['cargo'],
        y=df_agg['salario_medio'],
        name='Outros Cargos',
        marker_color='#6A8EAE',  # Azul acinzentado
        hovertemplate='<b>Cargo:</b> %{x}<br><b>Salário:</b> $%{y:,.0f}<extra></extra>'
    )
)

# Adicionar Data Scientists em destaque
df_ds = df_agg[df_agg['destaque'] == 'Data Scientist']
if not df_ds.empty:
    fig2.add_trace(
        go.Bar(
            x=df_ds['cargo'],
            y=df_ds['salario_medio'],
            name='Data Scientist',
            marker_color='#FF6B6B',  # Vermelho claro
            hovertemplate='<b>Cargo:</b> %{x}<br><b>Salário:</b> $%{y:,.0f}<extra></extra>'
        )
    )

# Configurar layout
fig2.update_layout(
    template=dark_template,
    title='<b>Salário Médio por Cargo</b><br><sup>Destaque para Data Scientists</sup>',
    xaxis_title='Cargo',
    yaxis_title='Salário Médio (USD)',
    xaxis_tickangle=-45,
    yaxis_tickprefix='$',
    yaxis_tickformat=',.0f',
    barmode='group',
    height=600,
    showlegend=True,
    margin=dict(l=20, r=20, t=80, b=20)
)

## 5. Exibição dos Gráficos ===================================================
fig.show()
fig2.show()

## Opção para exportar
# fig.write_html("salario_por_pais_dark.html")
# fig2.write_html("salario_por_cargo_dark.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## 1. Configuração do Tema Escuro =============================================
dark_template = {
    'layout': {
        'paper_bgcolor': 'rgba(0,0,0,0)',
        'plot_bgcolor': 'rgba(0,0,0,0)',
        'font': {'color': 'white'},
        'xaxis': {
            'gridcolor': 'rgba(100,100,100,0.2)',
            'linecolor': 'rgba(100,100,100,0.8)',
            'zerolinecolor': 'rgba(100,100,100,0.4)'
        },
        'yaxis': {
            'gridcolor': 'rgba(100,100,100,0.2)',
            'linecolor': 'rgba(100,100,100,0.8)',
            'zerolinecolor': 'rgba(100,100,100,0.4)'
        },
        'hoverlabel': {
            'bgcolor': '#1a1a1a',
            'font': {'color': 'white'}
        }
    }
}

## 2. Filtrar apenas Data Scientists ==========================================
# Filtro para pegar variações do nome (Data Scientist, Data Science, etc.)
df_ds = df_limpo[df_limpo['cargo'].str.contains('Data Scien', case=False, regex=True)]

# Agrupar por país - calculando média, mediana e contagem
df_ds_agg = df_ds.groupby('residencia')['usd'].agg(
    ['mean', 'median', 'count', 'std']).reset_index()
df_ds_agg.rename(columns={
    'mean': 'salario_medio',
    'median': 'salario_mediano',
    'count': 'qtd_registros',
    'std': 'desvio_padrao'
}, inplace=True)

# Filtrar países com pelo menos 5 registros (ajuste conforme necessário)
df_ds_agg = df_ds_agg[df_ds_agg['qtd_registros'] >= 5]

# Ordenar por salário médio
df_ds_agg = df_ds_agg.sort_values('salario_medio', ascending=False)

## 3. Gráfico Principal - Salário Médio por País ==============================
fig = px.bar(
    df_ds_agg,
    x='residencia',
    y='salario_medio',
    color='salario_medio',
    color_continuous_scale='RdYlGn_r',  # Escala vermelho-amarelo-verde (invertida)
    hover_data=['salario_mediano', 'qtd_registros', 'desvio_padrao'],
    labels={
        'residencia': 'País',
        'salario_medio': 'Salário Médio (USD)',
        'salario_mediano': 'Salário Mediano',
        'qtd_registros': 'N° de Registros',
        'desvio_padrao': 'Desvio Padrão'
    },
    title='<b>Salário de Data Scientists por País</b><br><sup>Análise Comparativa (2025)</sup>',
    height=600,
    template=dark_template
)

# Personalizar hover e layout
fig.update_traces(
    hovertemplate=(
        "<b>País:</b> %{x}<br>"
        "<b>Média:</b> $%{y:,.0f}<br>"
        "<b>Mediana:</b> $%{customdata[0]:,.0f}<br>"
        "<b>Registros:</b> %{customdata[1]}<br>"
        "<b>Desvio Padrão:</b> $%{customdata[2]:,.0f}"
    ),
    marker_line_color='white',
    marker_line_width=1
)

fig.update_layout(
    xaxis_tickangle=-45,
    yaxis_tickprefix='$',
    yaxis_tickformat=',.0f',
    coloraxis_colorbar=dict(
        title='Salário Médio',
        tickprefix='$',
        ticksuffix=' USD'
    ),
    margin=dict(l=20, r=20, t=80, b=20),
    hovermode='x unified'
)

## 4. Gráfico de Dispersão - Salário vs Estabilidade ==========================
# (Mostra relação entre média e desvio padrão)
fig2 = px.scatter(
    df_ds_agg,
    x='salario_medio',
    y='desvio_padrao',
    size='qtd_registros',
    color='residencia',
    hover_name='residencia',
    log_x=True,
    labels={
        'salario_medio': 'Salário Médio (USD) - Escala Log',
        'desvio_padrao': 'Desvio Padrão Salarial',
        'qtd_registros': 'N° de Registros',
        'residencia': 'País'
    },
    title='<b>Relação: Salário Médio vs Variabilidade</b><br><sup>Tamanho do círculo = N° de registros</sup>',
    height=600,
    template=dark_template
)

fig2.update_traces(
    marker=dict(line=dict(width=1, color='white')),
    selector=dict(mode='markers')
)

fig2.update_layout(
    xaxis_tickprefix='$',
    xaxis_tickformat=',.0f',
    yaxis_tickprefix='$',
    yaxis_tickformat=',.0f',
    margin=dict(l=20, r=20, t=80, b=20)
)

## 5. Exibir os gráficos ======================================================
fig.show()
fig2.show()

# Opção para exportar
# fig.write_html("data_scientists_salarios_pais.html")
# fig2.write_html("data_scientists_variabilidade.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Tarefa de Casa para proxima aula Salario medio por Pais, por Cargo e deixa em evidencia o Cargo de Ciencia de Dados(Data Scients)

# %%
df_limpo.head(10)
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
# 5  2025      junior  integral       Data Engineer    80000   USD   80000
# 6  2025      senior  integral      Data Scientist   185000   USD  185000
# 7  2025      senior  integral      Data Scientist   148000   USD  148000
# 8  2025       pleno  integral      Data Scientist   135000   USD  135000
# 9  2025       pleno  integral      Data Scientist   108000   USD  108000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# ...

# %% [markdown]
# 1. Definição do Objetivo Principal
#
# Problema: "Mostrar salários de Data Scientists por país com destaque e legibilidade em tema escuro"
#
# Solução Adotada:
#
#     Filtragem rigorosa para isolar apenas Data Scientists
#
#     Seleção das métricas mais relevantes (média, mediana, desvio padrão)
#
#     Dois gráficos complementares para análise completa

# %%
# Filtro inteligente que captura variações do cargo
df_ds = df_limpo[df_limpo['cargo'].str.contains('Data Scien', case=False, regex=True)]
df_ds.head()
# Out:
#      ano senioridade  contrato           cargo  salario moeda     usd  \
# 6   2025      senior  integral  Data Scientist   185000   USD  185000
# 7   2025      senior  integral  Data Scientist   148000   USD  148000
# 8   2025       pleno  integral  Data Scientist   135000   USD  135000
# 9   2025       pleno  integral  Data Scientist   108000   USD  108000
# 65  2025      senior  integral  Data Scientist   258000   USD  258000
#
#    residencia      remoto empresa tamanho_empresa
# 6          US  presencial      US           media
# 7          US  presencial      US           media
# 8          CA  presencial      CA           media
# 9          CA  presencial      CA           media
# 65         US  presencial      US           media

# %%
# Agregação múltipla para captar diferentes aspectos
df_ds_agg = df_ds.groupby('residencia')['usd'].agg(
    ['mean', 'median', 'count', 'std']).reset_index()

df_ds_agg.head(10)
# Out:
#   residencia           mean    median  count           std
# 0         AD   50745.000000   50745.0      1           NaN
# 1         AE  115000.000000  115000.0      1           NaN
# 2         AR   42000.000000   45000.0      5  12549.900398
# 3         AT   50975.213115   46842.0     61  18131.304938
# 4         AU  109900.882353  107713.0     51  37940.570456
# 5         BE   66790.750000   65551.0      4  13160.406943
# 6         BG  152500.000000  152500.0      2  17677.669530
# 7         BR   73720.909091   34000.0     11  69170.927196
# 8         CA  140380.066540  135000.0    526  54913.754391
# 9         CH  154315.142857  122638.0      7  77090.671853

# %%
df_ds.head()
# Out:
#      ano senioridade  contrato           cargo  salario moeda     usd  \
# 6   2025      senior  integral  Data Scientist   185000   USD  185000
# 7   2025      senior  integral  Data Scientist   148000   USD  148000
# 8   2025       pleno  integral  Data Scientist   135000   USD  135000
# 9   2025       pleno  integral  Data Scientist   108000   USD  108000
# 65  2025      senior  integral  Data Scientist   258000   USD  258000
#
#    residencia      remoto empresa tamanho_empresa
# 6          US  presencial      US           media
# 7          US  presencial      US           media
# 8          CA  presencial      CA           media
# 9          CA  presencial      CA           media
# 65         US  presencial      US           media

# %%
df_ds.tail()
# Out:
#          ano senioridade  contrato                     cargo  salario moeda  \
# 133340  2021       pleno  integral            Data Scientist   160000   SGD
# 133344  2020      senior  integral            Data Scientist   412000   USD
# 133345  2021       pleno  integral  Principal Data Scientist   151000   USD
# 133346  2020      junior  integral            Data Scientist   105000   USD
# 133348  2021      senior  integral            Data Scientist  7000000   INR
#
#            usd residencia   remoto empresa tamanho_empresa
# 133340  119059         SG   remoto      IL           media
# 133344  412000         US   remoto      US          grande
# 133345  151000         US   remoto      US          grande
# 133346  105000         US   remoto      US         pequena
# 133348   94665         IN  hibrido      IN          grande

# %%
df_residencia=df_ds.groupby('residencia')['usd'].agg(['mean', 'median', 'count', 'std']).reset_index()
df_residencia.head()
# Out:
#   residencia           mean    median  count           std
# 0         AD   50745.000000   50745.0      1           NaN
# 1         AE  115000.000000  115000.0      1           NaN
# 2         AR   42000.000000   45000.0      5  12549.900398
# 3         AT   50975.213115   46842.0     61  18131.304938
# 4         AU  109900.882353  107713.0     51  37940.570456

# %%
df_residencia = df_residencia.sort_values(by='mean', ascending=True)
df_residencia.head()
# Out:
#    residencia      mean   median  count          std
# 15         EC  16000.00  16000.0      1          NaN
# 50         TW  17282.50  17282.5      2  2830.548445
# 39         PK  21000.00  21000.0      1          NaN
# 24         HU  23935.75  21162.0      4  8187.339998
# 43         RS  25532.00  25532.0      1          NaN

# %%
#Grafico de Barra
fig = px.bar(df_residencia, x='residencia', y='mean')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Claro! Que tal fazer um exercício onde você cria um gráfico de barras para visualizar a distribuição de salários por nível de senioridade, mas com uma pequena variação?
#
# Exercício:
#
# Utilize a base de dados que você já tem.
# Crie um gráfico de barras que mostre a média salarial (em USD) por nível de senioridade, mas agora adicione uma comparação entre os salários de homens e mulheres dentro de cada nível de senioridade.
# Para isso, você precisará filtrar os dados por gênero e, em seguida, calcular a média salarial para cada combinação de nível de senioridade e gênero.
# Utilize a biblioteca Seaborn para criar o gráfico e adicione cores diferentes para cada gênero.
# Esse exercício vai te ajudar a praticar a manipulação de dados e a visualização de informações de forma mais complexa. Boa sorte!

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Adicionar uma coluna de gênero fictícia para fins de demonstração
# Em um cenário real, essa informação viria da fonte de dados
np.random.seed(42) # para reprodutibilidade
df_limpo['genero'] = np.random.choice(['Masculino', 'Feminino'], size=len(df_limpo))
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa     genero
# 0         US      remoto      US           media  Masculino
# 1         US      remoto      US           media   Feminino
# 2         AU  presencial      AU           media  Masculino
# 3         AU  presencial      AU           media  Masculino
# 4         US  presencial      US           media  Masculino

# %%
# Calcular a média salarial por senioridade e gênero
df_salario_genero = df_limpo.groupby(['senioridade', 'genero'])['usd'].mean().reset_index()
df_salario_genero.head()
# Out:
#   senioridade     genero            usd
# 0   executivo   Feminino  202757.252967
# 1   executivo  Masculino  201297.170106
# 2      junior   Feminino   99049.025108
# 3      junior  Masculino   99020.753717
# 4       pleno   Feminino  142925.962002

# %%
# Definir a ordem das senioridades para o gráfico
ordem_senioridade = ["junior", "pleno", "senior", "executivo"]

# %%
# Criar o gráfico de barras comparando salários por senioridade e gênero
plt.figure(figsize=(10, 6))
sns.barplot(data=df_salario_genero, x="senioridade", y="usd", hue="genero", order=ordem_senioridade, palette="viridis")

plt.title("Média Salarial por Senioridade e Gênero")
plt.xlabel("Senioridade")
plt.ylabel("Média Salarial (USD)")
plt.legend(title="Gênero")
plt.show()

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 46.5 MB/s eta 0:00:00
# ...

# %%
import pycountry

# %%
# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa     genero residencia_iso3
# 0         US      remoto      US           media  Masculino             USA
# 1         US      remoto      US           media   Feminino             USA
# 2         AU  presencial      AU           media  Masculino             AUS
# 3         AU  presencial      AU           media  Masculino             AUS
# 4         US  presencial      US           media  Masculino             USA

# %%
df_limpo.to_csv('dados-imersao-final-Dia03.csv', index=False)
